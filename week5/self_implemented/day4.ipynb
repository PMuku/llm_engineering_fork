# %%
from pathlib import Path
import sys

for parent in (Path.cwd(), *Path.cwd().parents):
    self_implemented = parent / "week5" / "self_implemented"
    if (self_implemented / "evaluation" / "test.py").exists():
        sys.path.insert(0, str(parent / "week5"))
        sys.path.insert(0, str(self_implemented))
        break

from self_implemented.evaluation import test

# %%
tests = test.load_tests()
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from self_implemented.evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.16666666666666666, ndcg=0.29420493957109245, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)

# %%
eval
# Out:
# AnswerEval(feedback="The generated answer is highly accurate in naming the winner and the award. However, it omits the winner's last name ('Thompson') which was present in the reference answer, making it less complete than necessary. It still provides a direct and accurate answer to the question.\n\n(Self-correction/Note: The prompt is designed for an evaluator. The evaluator must follow the instructions strictly.)", accuracy=4.0, completeness=4.0, relevance=5.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The generated answer is highly accurate in naming the winner and the award. However, it omits the winner's last name ('Thompson') which was present in the reference answer, making it less complete than necessary. It still provides a direct and accurate answer to the question.
#
# (Self-correction/Note: The prompt is designed for an evaluator. The evaluator must follow the instructions strictly.)
# 4.0
# 4.0
# 5.0
